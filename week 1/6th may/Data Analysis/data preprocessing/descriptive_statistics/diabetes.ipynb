# %%
import pandas as pd
import numpy as np
from scipy import stats
from IPython.display import display

# %%
csv_path = (r"C:\Users\NikitaRampurkarV-Sof\nikita_vsoft\tasks\Data Analysis\data preprocessing\diabetes.csv")  # Change this to your actual file path
df = pd.read_csv(csv_path)

# %%
num_df = df.select_dtypes(include='number')

# %%
stats_df = pd.DataFrame(index=num_df.columns)

# %%
stats_df['Mean'] = num_df.mean()
stats_df['Median'] = num_df.median()
stats_df['Mode'] = num_df.mode().iloc[0]  # First mode
stats_df['Min'] = num_df.min()
stats_df['Max'] = num_df.max()
stats_df['Standard Deviation'] = num_df.std()
stats_df['Variance'] = num_df.var()
stats_df['Standard Error'] = num_df.sem()
stats_df['25th Percentile'] = num_df.quantile(0.25)
stats_df['50th Percentile (Median)'] = num_df.quantile(0.5)
stats_df['75th Percentile'] = num_df.quantile(0.75)
stats_df['Skewness'] = num_df.skew()
stats_df['Kurtosis'] = num_df.kurt()

# %%
print("📊 Descriptive Statistics for Numeric Columns:")
display(stats_df.round(4))
# Out:
# 📊 Descriptive Statistics for Numeric Columns:
#                               Mean    Median    Mode     Min     Max  \
# Pregnancies                 3.8451    3.0000   1.000   0.000   17.00
# Glucose                   120.8945  117.0000  99.000   0.000  199.00
# BloodPressure              69.1055   72.0000  70.000   0.000  122.00
# SkinThickness              20.5365   23.0000   0.000   0.000   99.00
# Insulin                    79.7995   30.5000   0.000   0.000  846.00
# BMI                        31.9926   32.0000  32.000   0.000   67.10
# DiabetesPedigreeFunction    0.4719    0.3725   0.254   0.078    2.42
# Age                        33.2409   29.0000  22.000  21.000   81.00
# Outcome                     0.3490    0.0000   0.000   0.000    1.00
#
#                           Standard Deviation    Variance  Standard Error  \
# Pregnancies                           3.3696     11.3541          0.1216
# Glucose                              31.9726   1022.2483          1.1537
# BloodPressure                        19.3558    374.6473          0.6984
# SkinThickness                        15.9522    254.4732          0.5756
# Insulin                             115.2440  13281.1801          4.1585
# BMI                                   7.8842     62.1600          0.2845
# DiabetesPedigreeFunction              0.3313      0.1098          0.0120
# Age                                  11.7602    138.3030          0.4244
# Outcome                               0.4770      0.2275          0.0172
#
#                           25th Percentile  50th Percentile (Median)  \
# Pregnancies                        1.0000                    3.0000
# Glucose                           99.0000                  117.0000
# BloodPressure                     62.0000                   72.0000
# SkinThickness                      0.0000                   23.0000
# Insulin                            0.0000                   30.5000
# BMI                               27.3000                   32.0000
# DiabetesPedigreeFunction           0.2438                    0.3725
# Age                               24.0000                   29.0000
# Outcome                            0.0000                    0.0000
#
#                           75th Percentile  Skewness  Kurtosis
# Pregnancies                        6.0000    0.9017    0.1592
# Glucose                          140.2500    0.1738    0.6408
# BloodPressure                     80.0000   -1.8436    5.1802
# SkinThickness                     32.0000    0.1094   -0.5201
# Insulin                          127.2500    2.2723    7.2143
# BMI                               36.6000   -0.4290    3.2904
# DiabetesPedigreeFunction           0.6262    1.9199    5.5950
# Age                               41.0000    1.1296    0.6432
# Outcome                            1.0000    0.6350   -1.6009

# %%
# --- One-Way ANOVA: Between each pair of numeric columns ---
anova_results = {}
columns = num_df.columns
for i in range(len(columns)):
    for j in range(i + 1, len(columns)):
        f_stat, p_val = stats.f_oneway(num_df[columns[i]], num_df[columns[j]])
        anova_results[f"{columns[i]} vs {columns[j]}"] = {
            'F-statistic': f_stat,
            'p-value': p_val
        }

anova_df = pd.DataFrame(anova_results).T

# %%
# Display ANOVA Results
print("\n📈 One-Way ANOVA Results (pairwise):")
display(anova_df.round(4))
# Out:
# 📈 One-Way ANOVA Results (pairwise):
#                                            F-statistic  p-value
# Pregnancies vs Glucose                      10179.9746   0.0000
# Pregnancies vs BloodPressure                 8473.6809   0.0000
# Pregnancies vs SkinThickness                  804.9103   0.0000
# Pregnancies vs Insulin                        333.3187   0.0000
# Pregnancies vs BMI                           8276.9701   0.0000
# Pregnancies vs DiabetesPedigreeFunction       762.2707   0.0000
# Pregnancies vs Age                           4434.4059   0.0000
# Pregnancies vs Outcome                        810.5151   0.0000
# Glucose vs BloodPressure                     1474.5971   0.0000
# Glucose vs SkinThickness                     6058.5634   0.0000
# Glucose vs Insulin                             90.6776   0.0000
# Glucose vs BMI                               5597.4599   0.0000
# Glucose vs DiabetesPedigreeFunction         10893.6791   0.0000
# Glucose vs Age                               5084.3662   0.0000
# Glucose vs Outcome                          10914.6726   0.0000
# BloodPressure vs SkinThickness               2879.6909   0.0000
# BloodPressure vs Insulin                        6.4317   0.0113
# BloodPressure vs BMI                         2421.7033   0.0000
# BloodPressure vs DiabetesPedigreeFunction    9653.5016   0.0000
# BloodPressure vs Age                         1925.8280   0.0000
# BloodPressure vs Outcome                     9685.0681   0.0000
# SkinThickness vs Insulin                      199.2735   0.0000
# SkinThickness vs BMI                          318.3317   0.0000
# SkinThickness vs DiabetesPedigreeFunction    1214.4846   0.0000
# SkinThickness vs Age                          315.5921   0.0000
# SkinThickness vs Outcome                     1228.8422   0.0000
# Insulin vs BMI                                131.5461   0.0000
# Insulin vs DiabetesPedigreeFunction           363.8896   0.0000
# Insulin vs Age                                124.0581   0.0000
# Insulin vs Outcome                            365.0149   0.0000
# BMI vs DiabetesPedigreeFunction             12253.9405   0.0000
# BMI vs Age                                      5.9699   0.0147
# BMI vs Outcome                              12326.3980   0.0000
# DiabetesPedigreeFunction vs Age              5958.1510   0.0000
# DiabetesPedigreeFunction vs Outcome            34.4053   0.0000
# Age vs Outcome                               5997.8330   0.0000
